# %%
from src.eda_vector import *
from src.lda_model import *
from src.model import *

# %%
X_train, X_test, y_train, y_test = get_data(num_samples=100000, balanced=True)
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3185: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3185: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):

# %%
custom_stops = ['https', 'rt', 'co', 'amp', 'via', 'go', 'get', 'said', 'say', 'news', 'new', 'make', 'want', 
                'says', 'would', 'let', 'video', 'like']

# %%
vectors = EDA_vec(X_train, y_train)

# %%
vectors.legit_dist, vectors.troll_dist
# Out:
# (0.5, 0.5)

# %%
vectors.add_stop_words(custom_stops)

# %%
vocab, matrix = vectors.vectorize(min_df=0.0001)

# %%
vectors.word_freq()

# %%
vectors.chart_word_freq(low_words=0, high_words=6)

# %%
vectors.chart_top_words(low=-1, high=9)
# Out:
# /home/ubuntu/topic_modeling_2016/src/eda_vector.py:109: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(legit_words)
# /home/ubuntu/topic_modeling_2016/src/eda_vector.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_xticklabels(troll_words)

# %%
vectors.top_words()
# Out:
# (Index(['hillary', 'world', 'people', 'clinton', 'black'], dtype='object'),
#  Index(['trump', 'clinton', 'donald', 'hillary', 'donald trump'], dtype='object'))

# %%
lda = LDA_model(topics=5)
lda.fit(matrix, y_train, vocab)
phi = lda.phi()
theta = lda.theta()

# %%
lda.display_topics(num_words=15)
# Out:
# Topic 0:
# time media could taxes going women good bill show today got rally every much russia
# Topic 1:
# debate know gop man right debatenight watch presidential american way still read first tonight cnn
# Topic 2:
# people president obama one vote cnn back support supporters great poll last world take family
# Topic 3:
# election us america win need day white candidate voters party vote great presidential every first
# Topic 4:
# campaign think tax never khan even really see years look tonight first family great could

# %%
lda.plot_top_words()

# %%
lda.topic_likelihood()
# Out:
# array([1, 0, 0, ..., 4, 0, 0])

# %%
lda.plot_topics_by_class()

# %%
score = lda.coherance_score

# %%
score
# Out:
# <bound method LDA_model.coherance_score of <src.lda_model.LDA_model object at 0x7fb4dcf5e908>>

# %%
len(vocab)
# Out:
# 67

# %%
# lda_model - LatentDirichletAllocation()
# vect - CountVectorizer()
# texts - the list of tokenized words

num_topics = np.arange(2,20,1)
score_array = np.zeros(len(num_topics))
for i,num in enumerate(num_topics):
    model = LatentDirichletAllocation(n_components=num, max_iter=6, learning_method='online', n_jobs=-1)
    model.fit(count_vec)
    metric_coherence_gensim(measure='c_v', 
                            top_n=25, 
                            topic_word_distrib=model.components_, 
                            dtm=count_df, 
                            vocab=np.array([x for x in vocab_count]), 
                            )
    
    print(num, np.mean(scores))
    score_array[i] = np.mean(scores)
